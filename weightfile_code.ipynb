# %%
from tensorflow.keras import backend as K
K.clear_session()

# %%
# !pip install rarfile
# Out:
# Collecting rarfile
#   Downloading rarfile-4.2-py3-none-any.whl.metadata (4.4 kB)
# Downloading rarfile-4.2-py3-none-any.whl (29 kB)
# Installing collected packages: rarfile
# Successfully installed rarfile-4.2

# %%
import gdown
import rarfile
import os

# Correct URL after permissions are updated
url = 'https://drive.google.com/uc?id=1ObO-pLyN4vVmL7tGW3RrkciDlnnGU2qX'
output_rar = '/content/Wheat.rar'

# Download the RAR file
gdown.download(url, output_rar, quiet=False)

# Check if the downloaded file is valid before extracting
if os.path.exists(output_rar):
    try:
        # Try to open the downloaded file as a RAR file
        with rarfile.RarFile(output_rar, 'r') as rar_ref:
            rar_ref.extractall('/content')
        print("File extracted successfully!")
    except rarfile.NotRarFile:
        print("Error: The downloaded file is not a valid RAR archive.")
else:
    print("Error: File not found.")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1ObO-pLyN4vVmL7tGW3RrkciDlnnGU2qX
# From (redirected): https://drive.google.com/uc?id=1ObO-pLyN4vVmL7tGW3RrkciDlnnGU2qX&confirm=t&uuid=8e2e710c-f14b-4d6e-9365-5cc72fdda2fb
# To: /content/Wheat.rar
# 100%|██████████| 234M/234M [00:18<00:00, 13.0MB/s]
# File extracted successfully!

# %%
# Path to the extracted dataset folder

dataset = '/content/Wheat'

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Conv2D, MaxPooling2D, DepthwiseConv2D, BatchNormalization, LeakyReLU, Concatenate
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import matplotlib.pyplot as plt  # For plotting
import pandas as pd  # For displaying confusion matrix

# Directory for the dataset
data_dir = dataset  # Replace with your dataset path

# Function to create InceptionV3 from scratch (only base part for feature extraction)
def inceptionv3_base(input_shape=(224, 224, 3)):
    inputs = layers.Input(shape=input_shape)

    # Initial Conv Layers (first few layers of InceptionV3)
    x = Conv2D(32, (3, 3), strides=(2, 2), padding='valid', activation=None)(inputs)
    x = LeakyReLU(alpha=0.1)(x)  # Replace ReLU with LeakyReLU
    x = Conv2D(32, (3, 3), padding='valid', activation=None)(x)
    x = LeakyReLU(alpha=0.1)(x)  # Replace ReLU with LeakyReLU
    x = Conv2D(64, (3, 3), padding='same', activation=None)(x)
    x = LeakyReLU(alpha=0.1)(x)  # Replace ReLU with LeakyReLU
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='valid')(x)

    # Rest of the InceptionV3 blocks (simplified)
    x = Conv2D(80, (1, 1), padding='valid', activation=None)(x)
    x = LeakyReLU(alpha=0.1)(x)  # Replace ReLU with LeakyReLU
    x = Conv2D(192, (3, 3), padding='valid', activation=None)(x)
    x = LeakyReLU(alpha=0.1)(x)  # Replace ReLU with LeakyReLU
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='valid')(x)

    # Add additional inception blocks or custom blocks as needed (for brevity, simplified here)
    x = GlobalAveragePooling2D()(x)  # Global Avg Pooling as a common InceptionV3 trait
    return Model(inputs, x)  # Return the feature extractor

# Function to create Custom-CNN from scratch (used for feature extraction after InceptionV3)
def custom_cnn_base(input_shape=(224, 224, 3)):
    inputs = layers.Input(shape=input_shape)

    # Block 1
    x = Conv2D(32, (3, 3), strides=(2, 2), padding='same')(inputs)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.1)(x)  # Replace ReLU with LeakyReLU

    # Depthwise Separable Convolution Blocks
    # Block 2
    x = DepthwiseConv2D((3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.1)(x)  # Replace ReLU with LeakyReLU
    x = Conv2D(64, (1, 1), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.1)(x)  # Replace ReLU with LeakyReLU

    # Block 3
    x = DepthwiseConv2D((3, 3), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.1)(x)  # Replace ReLU with LeakyReLU
    x = Conv2D(128, (1, 1), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.1)(x)  # Replace ReLU with LeakyReLU

    # Global Average Pooling at the end of Custom-CNN
    x = GlobalAveragePooling2D()(x)

    return Model(inputs, x)  # Return the feature extractor

# Build the InceptionV3 feature extraction part
inception_base = inceptionv3_base(input_shape=(224, 224, 3))

# Build the Custom-CNN feature extraction part
custom_cnn_base = custom_cnn_base(input_shape=(224, 224, 3))

# Combine the features extracted from both models
inputs = layers.Input(shape=(224, 224, 3))

# Extract features from both models
inception_features = inception_base(inputs)
custom_cnn_features = custom_cnn_base(inputs)

# Concatenate the features from both models
x = Concatenate()([inception_features, custom_cnn_features])

# Fully connected layers after feature extraction
x = Dense(1024, activation='relu')(x)
outputs = Dense(10, activation='softmax')(x)  # Adjust for your number of classes

# Create the hybrid model
hybrid_model = Model(inputs, outputs)

# Print the hybrid model summary
hybrid_model.summary()

# Compile the hybrid model
hybrid_model.compile(optimizer=Adam(learning_rate=0.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# ImageDataGenerators for loading the dataset
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# Data generators for training, validation, and testing
train_generator = train_datagen.flow_from_directory(
    os.path.join(data_dir, 'Train'),
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=True
)

val_generator = val_datagen.flow_from_directory(
    os.path.join(data_dir, 'Validation'),
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)

test_generator = test_datagen.flow_from_directory(
    os.path.join(data_dir, 'Test'),
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)

# Training the hybrid model
history = hybrid_model.fit(train_generator, epochs=50, validation_data=val_generator)

# Plot training results
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Helper function to evaluate the hybrid model on test data
def evaluate_model(test_generator, model, classes, title="Performance"):
    y_test_pred = model.predict(test_generator)
    y_test_pred = np.argmax(y_test_pred, axis=1)

    precision = precision_score(test_generator.labels, y_test_pred, average='weighted')
    recall = recall_score(test_generator.labels, y_test_pred, average='weighted')
    f1 = f1_score(test_generator.labels, y_test_pred, average='weighted')
    accuracy = accuracy_score(test_generator.labels, y_test_pred)

    print(f"\n{title}")
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1 Score:", f1)
    print("Accuracy:", accuracy)

    # Display the confusion matrix
    confusion = confusion_matrix(test_generator.labels, y_test_pred)
    confusion_df = pd.DataFrame(confusion, index=classes, columns=classes)
    print("Confusion Matrix:\n", confusion_df)

# Test the hybrid model on the test set
evaluate_model(test_generator, hybrid_model, ['Brown_Rust', 'Healthy', 'Yellow_Rust'], title="Performance on Test Data")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2             │ (None, 224, 224, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ functional (Functional)   │ (None, 192)            │        172,272 │ input_layer_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ functional_1 (Functional) │ (None, 128)            │         13,568 │ input_layer_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 320)            │              0 │ functional[0][0],      │
# │                           │                        │                │ functional_1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 1024)           │        328,704 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 10)             │         10,250 │ dense[0][0]            │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 524,794 (2.00 MB)
#  Trainable params: 524,154 (2.00 MB)
#  Non-trainable params: 640 (2.50 KB)
# Found 2042 images belonging to 3 classes.
# Found 293 images belonging to 3 classes.
# Found 594 images belonging to 3 classes.
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 54s 547ms/step - accuracy: 0.4592 - loss: 1.6126 - val_accuracy: 0.3413 - val_loss: 1.2783
# Epoch 2/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 40s 115ms/step - accuracy: 0.7405 - loss: 0.7043 - val_accuracy: 0.3413 - val_loss: 1.5825
# Epoch 3/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 10s 117ms/step - accuracy: 0.7432 - loss: 0.6532 - val_accuracy: 0.3413 - val_loss: 1.6958
# Epoch 4/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - accuracy: 0.7729 - loss: 0.5888 - val_accuracy: 0.3413 - val_loss: 1.5876
# Epoch 5/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 124ms/step - accuracy: 0.7860 - loss: 0.5420 - val_accuracy: 0.3413 - val_loss: 1.8848
# Epoch 6/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 121ms/step - accuracy: 0.7976 - loss: 0.5211 - val_accuracy: 0.3720 - val_loss: 1.8742
# Epoch 7/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.8056 - loss: 0.4981 - val_accuracy: 0.5119 - val_loss: 1.6579
# Epoch 8/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 128ms/step - accuracy: 0.8027 - loss: 0.4782 - val_accuracy: 0.5427 - val_loss: 1.4934
# Epoch 9/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - accuracy: 0.8089 - loss: 0.4617 - val_accuracy: 0.5188 - val_loss: 1.2818
# Epoch 10/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 123ms/step - accuracy: 0.8240 - loss: 0.4285 - val_accuracy: 0.7065 - val_loss: 0.6303
# Epoch 11/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 130ms/step - accuracy: 0.8356 - loss: 0.4214 - val_accuracy: 0.8055 - val_loss: 0.4565
# Epoch 12/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - accuracy: 0.8322 - loss: 0.4150 - val_accuracy: 0.8089 - val_loss: 0.4389
# Epoch 13/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 121ms/step - accuracy: 0.8288 - loss: 0.4036 - val_accuracy: 0.8259 - val_loss: 0.3653
# Epoch 14/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 132ms/step - accuracy: 0.8299 - loss: 0.4000 - val_accuracy: 0.8498 - val_loss: 0.3500
# Epoch 15/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 10s 124ms/step - accuracy: 0.8520 - loss: 0.3671 - val_accuracy: 0.8601 - val_loss: 0.3401
# Epoch 16/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 8s 115ms/step - accuracy: 0.8617 - loss: 0.3406 - val_accuracy: 0.8396 - val_loss: 0.3734
# Epoch 17/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 129ms/step - accuracy: 0.8596 - loss: 0.3495 - val_accuracy: 0.8635 - val_loss: 0.3085
# Epoch 18/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - accuracy: 0.8660 - loss: 0.3327 - val_accuracy: 0.8669 - val_loss: 0.3020
# Epoch 19/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 10s 112ms/step - accuracy: 0.8657 - loss: 0.3137 - val_accuracy: 0.8805 - val_loss: 0.2838
# Epoch 20/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 10s 113ms/step - accuracy: 0.8682 - loss: 0.3349 - val_accuracy: 0.8942 - val_loss: 0.2747
# Epoch 21/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.8612 - loss: 0.3268 - val_accuracy: 0.8771 - val_loss: 0.2777
# Epoch 22/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 131ms/step - accuracy: 0.8642 - loss: 0.3124 - val_accuracy: 0.8840 - val_loss: 0.3014
# Epoch 23/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 119ms/step - accuracy: 0.8514 - loss: 0.3479 - val_accuracy: 0.8908 - val_loss: 0.2644
# Epoch 24/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 10s 114ms/step - accuracy: 0.8584 - loss: 0.3323 - val_accuracy: 0.8703 - val_loss: 0.2815
# Epoch 25/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 128ms/step - accuracy: 0.8804 - loss: 0.3147 - val_accuracy: 0.8840 - val_loss: 0.2697
# Epoch 26/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 10s 129ms/step - accuracy: 0.8971 - loss: 0.2657 - val_accuracy: 0.8840 - val_loss: 0.2711
# Epoch 27/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 116ms/step - accuracy: 0.8843 - loss: 0.2760 - val_accuracy: 0.8703 - val_loss: 0.2706
# Epoch 28/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 121ms/step - accuracy: 0.8935 - loss: 0.2748 - val_accuracy: 0.9078 - val_loss: 0.2466
# Epoch 29/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 10s 114ms/step - accuracy: 0.9110 - loss: 0.2395 - val_accuracy: 0.8908 - val_loss: 0.2581
# Epoch 30/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 133ms/step - accuracy: 0.8794 - loss: 0.2895 - val_accuracy: 0.8942 - val_loss: 0.2596
# Epoch 31/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 130ms/step - accuracy: 0.9072 - loss: 0.2436 - val_accuracy: 0.8908 - val_loss: 0.2437
# Epoch 32/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9034 - loss: 0.2526 - val_accuracy: 0.9010 - val_loss: 0.2454
# Epoch 33/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 10s 115ms/step - accuracy: 0.9169 - loss: 0.2311 - val_accuracy: 0.8805 - val_loss: 0.2787
# Epoch 34/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 130ms/step - accuracy: 0.9123 - loss: 0.2437 - val_accuracy: 0.9181 - val_loss: 0.2460
# Epoch 35/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9156 - loss: 0.2259 - val_accuracy: 0.9010 - val_loss: 0.2458
# Epoch 36/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 10s 113ms/step - accuracy: 0.9084 - loss: 0.2222 - val_accuracy: 0.8874 - val_loss: 0.2502
# Epoch 37/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 10s 112ms/step - accuracy: 0.8980 - loss: 0.2357 - val_accuracy: 0.9044 - val_loss: 0.2458
# Epoch 38/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 136ms/step - accuracy: 0.9132 - loss: 0.2238 - val_accuracy: 0.8908 - val_loss: 0.2345
# Epoch 39/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 126ms/step - accuracy: 0.9089 - loss: 0.2574 - val_accuracy: 0.9044 - val_loss: 0.2239
# Epoch 40/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 112ms/step - accuracy: 0.9143 - loss: 0.2162 - val_accuracy: 0.8874 - val_loss: 0.2364
# Epoch 41/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 130ms/step - accuracy: 0.9156 - loss: 0.2112 - val_accuracy: 0.9113 - val_loss: 0.2321
# Epoch 42/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 127ms/step - accuracy: 0.8996 - loss: 0.2301 - val_accuracy: 0.8976 - val_loss: 0.2348
# Epoch 43/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 8s 114ms/step - accuracy: 0.9265 - loss: 0.1929 - val_accuracy: 0.9181 - val_loss: 0.2400
# Epoch 44/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - accuracy: 0.9247 - loss: 0.1845 - val_accuracy: 0.8976 - val_loss: 0.2375
# Epoch 45/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.9215 - loss: 0.2200 - val_accuracy: 0.8874 - val_loss: 0.2399
# Epoch 46/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 8s 115ms/step - accuracy: 0.9197 - loss: 0.2207 - val_accuracy: 0.9010 - val_loss: 0.2109
# Epoch 47/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 127ms/step - accuracy: 0.9081 - loss: 0.2171 - val_accuracy: 0.8874 - val_loss: 0.2436
# Epoch 48/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 10s 130ms/step - accuracy: 0.9284 - loss: 0.1965 - val_accuracy: 0.9044 - val_loss: 0.2399
# Epoch 49/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - accuracy: 0.9290 - loss: 0.1838 - val_accuracy: 0.8737 - val_loss: 0.2664
# Epoch 50/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.9354 - loss: 0.1858 - val_accuracy: 0.9147 - val_loss: 0.1969
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 239ms/step
#
# Performance on Test Data
# Precision: 0.9344923584077688
# Recall: 0.9343434343434344
# F1 Score: 0.9343902672137239
# Accuracy: 0.9343434343434344
# Confusion Matrix:
#               Brown_Rust  Healthy  Yellow_Rust
# Brown_Rust          182        8            6
# Healthy               8      184            5
# Yellow_Rust           9        3          189

# %%
# Save the model weights with the correct file extension
weights_path = "/content/model_weights.weights.h5"  # Specify the file name and path with the correct extension
hybrid_model.save_weights(weights_path)
print(f"Weights saved to {weights_path}")
# Out:
# Weights saved to /content/model_weights.weights.h5

# %%
from google.colab import files
files.download('/content/model_weights.weights.h5')  # Make sure this path is correct
