# %%
from tensorflow.keras import backend as K
K.clear_session()

# %%
# !pip install rarfile
# Out:
# Collecting rarfile
#   Downloading rarfile-4.2-py3-none-any.whl.metadata (4.4 kB)
# Downloading rarfile-4.2-py3-none-any.whl (29 kB)
# Installing collected packages: rarfile
# Successfully installed rarfile-4.2

# %%
import gdown
import rarfile
import os

# Correct URL after permissions are updated
url = 'https://drive.google.com/uc?id=1FAUSzwEDHfLN_McqFpQ6a3VWoc6h9qgw'
output_rar = '/content/WHEAT.rar'

# Download the RAR file
gdown.download(url, output_rar, quiet=False)

# Check if the downloaded file is valid before extracting
if os.path.exists(output_rar):
    try:
        # Try to open the downloaded file as a RAR file
        with rarfile.RarFile(output_rar, 'r') as rar_ref:
            rar_ref.extractall('/content')
        print("File extracted successfully!")
    except rarfile.NotRarFile:
        print("Error: The downloaded file is not a valid RAR archive.")
else:
    print("Error: File not found.")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1FAUSzwEDHfLN_McqFpQ6a3VWoc6h9qgw
# From (redirected): https://drive.google.com/uc?id=1FAUSzwEDHfLN_McqFpQ6a3VWoc6h9qgw&confirm=t&uuid=aee1085e-c91c-4e85-aeb1-aeddc262af17
# To: /content/WHEAT.rar
# 100%|██████████| 228M/228M [00:02<00:00, 89.3MB/s]
# File extracted successfully!

# %%
# Path to the extracted dataset folder

dataset = '/content/Wheat'

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Directory for the dataset
data_dir = dataset  # Replace with your dataset path

# Load VGG16 without pre-trained weights, include_top=False to customize the output
base_model = VGG16(weights=None, include_top=False, input_shape=(224, 224, 3))

# Make sure all layers are trainable
base_model.trainable = True

# Add custom classification head
inputs = tf.keras.Input(shape=(224, 224, 3))
x = base_model(inputs, training=True)
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='swish')(x)
outputs = Dense(10, activation='softmax')(x)  # Adjust number of classes as needed

# Build the full model
model = Model(inputs, outputs)

# Print model summary
model.summary()

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.00001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# ImageDataGenerators
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# Data generators
train_generator = train_datagen.flow_from_directory(
    os.path.join(data_dir, 'train'),
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=True
)

val_generator = val_datagen.flow_from_directory(
    os.path.join(data_dir, 'validation'),
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)

test_generator = test_datagen.flow_from_directory(
    os.path.join(data_dir, 'test'),
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)

# Train the model
history = model.fit(train_generator, epochs=40, validation_data=val_generator)

# Plot training results
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Evaluation function
def evaluate_model(test_generator, model, classes, title="Performance"):
    y_test_pred = model.predict(test_generator)
    y_test_pred = np.argmax(y_test_pred, axis=1)

    precision = precision_score(test_generator.labels, y_test_pred, average='weighted')
    recall = recall_score(test_generator.labels, y_test_pred, average='weighted')
    f1 = f1_score(test_generator.labels, y_test_pred, average='weighted')
    accuracy = accuracy_score(test_generator.labels, y_test_pred)

    print(f"\n{title}")
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1 Score:", f1)
    print("Accuracy:", accuracy)

    # Confusion matrix
    confusion = confusion_matrix(test_generator.labels, y_test_pred)
    confusion_df = pd.DataFrame(confusion, index=classes, columns=classes)
    print("Confusion Matrix:\n", confusion_df)

# Evaluate the model
evaluate_model(test_generator, model, ['Brown_Rust', 'Healthy', 'Yellow_Rust'], title="Performance on Test Data")
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ vgg16 (Functional)                   │ (None, 7, 7, 512)           │      14,714,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 512)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1024)                │         525,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │          10,250 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 15,250,250 (58.18 MB)
#  Trainable params: 15,250,250 (58.18 MB)
#  Non-trainable params: 0 (0.00 B)
# Found 4204 images belonging to 3 classes.
# Found 598 images belonging to 3 classes.
# Found 1198 images belonging to 3 classes.
# Epoch 1/40
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 151s 874ms/step - accuracy: 0.3174 - loss: 1.8415 - val_accuracy: 0.4097 - val_loss: 0.9844
# Epoch 2/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 63s 473ms/step - accuracy: 0.5870 - loss: 0.8746 - val_accuracy: 0.7324 - val_loss: 0.6302
# Epoch 3/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 65s 489ms/step - accuracy: 0.7107 - loss: 0.6312 - val_accuracy: 0.7926 - val_loss: 0.5422
# Epoch 4/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 66s 500ms/step - accuracy: 0.7491 - loss: 0.5917 - val_accuracy: 0.8043 - val_loss: 0.5022
# Epoch 5/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 509ms/step - accuracy: 0.7705 - loss: 0.5684 - val_accuracy: 0.8094 - val_loss: 0.4675
# Epoch 6/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 508ms/step - accuracy: 0.8047 - loss: 0.4814 - val_accuracy: 0.8060 - val_loss: 0.4718
# Epoch 7/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 509ms/step - accuracy: 0.8287 - loss: 0.4364 - val_accuracy: 0.8645 - val_loss: 0.4026
# Epoch 8/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 509ms/step - accuracy: 0.8380 - loss: 0.4262 - val_accuracy: 0.8562 - val_loss: 0.3595
# Epoch 9/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 509ms/step - accuracy: 0.8505 - loss: 0.4041 - val_accuracy: 0.8478 - val_loss: 0.3784
# Epoch 10/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 509ms/step - accuracy: 0.8528 - loss: 0.3955 - val_accuracy: 0.8612 - val_loss: 0.3512
# Epoch 11/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 509ms/step - accuracy: 0.8517 - loss: 0.3783 - val_accuracy: 0.8662 - val_loss: 0.3553
# Epoch 12/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 509ms/step - accuracy: 0.8752 - loss: 0.3414 - val_accuracy: 0.9047 - val_loss: 0.2917
# Epoch 13/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 69s 523ms/step - accuracy: 0.8796 - loss: 0.3218 - val_accuracy: 0.8896 - val_loss: 0.3269
# Epoch 14/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 508ms/step - accuracy: 0.8800 - loss: 0.3358 - val_accuracy: 0.9064 - val_loss: 0.3036
# Epoch 15/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 509ms/step - accuracy: 0.8790 - loss: 0.3274 - val_accuracy: 0.8829 - val_loss: 0.2993
# Epoch 16/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 69s 523ms/step - accuracy: 0.8764 - loss: 0.3402 - val_accuracy: 0.8863 - val_loss: 0.3155
# Epoch 17/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 508ms/step - accuracy: 0.8932 - loss: 0.3011 - val_accuracy: 0.9097 - val_loss: 0.2608
# Epoch 18/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 509ms/step - accuracy: 0.8930 - loss: 0.2916 - val_accuracy: 0.8813 - val_loss: 0.2972
# Epoch 19/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 69s 523ms/step - accuracy: 0.8897 - loss: 0.2947 - val_accuracy: 0.8629 - val_loss: 0.3363
# Epoch 20/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 509ms/step - accuracy: 0.8854 - loss: 0.2941 - val_accuracy: 0.9130 - val_loss: 0.2469
# Epoch 21/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 509ms/step - accuracy: 0.8916 - loss: 0.2875 - val_accuracy: 0.9181 - val_loss: 0.2322
# Epoch 22/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 69s 523ms/step - accuracy: 0.9003 - loss: 0.2689 - val_accuracy: 0.9264 - val_loss: 0.2391
# Epoch 23/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 509ms/step - accuracy: 0.9040 - loss: 0.2536 - val_accuracy: 0.9298 - val_loss: 0.2119
# Epoch 24/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 509ms/step - accuracy: 0.8983 - loss: 0.2723 - val_accuracy: 0.9298 - val_loss: 0.2277
# Epoch 25/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 509ms/step - accuracy: 0.9131 - loss: 0.2476 - val_accuracy: 0.9197 - val_loss: 0.2352
# Epoch 26/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 509ms/step - accuracy: 0.9157 - loss: 0.2265 - val_accuracy: 0.9147 - val_loss: 0.2300
# Epoch 27/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 509ms/step - accuracy: 0.9080 - loss: 0.2351 - val_accuracy: 0.9348 - val_loss: 0.1940
# Epoch 28/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 509ms/step - accuracy: 0.9069 - loss: 0.2280 - val_accuracy: 0.9181 - val_loss: 0.2272
# Epoch 29/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 509ms/step - accuracy: 0.9109 - loss: 0.2348 - val_accuracy: 0.9331 - val_loss: 0.2004
# Epoch 30/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 509ms/step - accuracy: 0.9107 - loss: 0.2193 - val_accuracy: 0.9281 - val_loss: 0.1894
# Epoch 31/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 69s 523ms/step - accuracy: 0.9186 - loss: 0.2073 - val_accuracy: 0.9381 - val_loss: 0.1738
# Epoch 32/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 509ms/step - accuracy: 0.9259 - loss: 0.1938 - val_accuracy: 0.9482 - val_loss: 0.1774
# Epoch 33/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 509ms/step - accuracy: 0.9151 - loss: 0.2371 - val_accuracy: 0.9247 - val_loss: 0.1946
# Epoch 34/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 509ms/step - accuracy: 0.9206 - loss: 0.2109 - val_accuracy: 0.9398 - val_loss: 0.1532
# Epoch 35/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 509ms/step - accuracy: 0.9290 - loss: 0.1813 - val_accuracy: 0.9415 - val_loss: 0.1638
# Epoch 36/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 509ms/step - accuracy: 0.9259 - loss: 0.1934 - val_accuracy: 0.9415 - val_loss: 0.1772
# Epoch 37/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 509ms/step - accuracy: 0.9212 - loss: 0.2032 - val_accuracy: 0.9465 - val_loss: 0.1557
# Epoch 38/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 509ms/step - accuracy: 0.9111 - loss: 0.2095 - val_accuracy: 0.9214 - val_loss: 0.1763
# Epoch 39/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 69s 523ms/step - accuracy: 0.9217 - loss: 0.1934 - val_accuracy: 0.9465 - val_loss: 0.1557
# Epoch 40/40
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 67s 509ms/step - accuracy: 0.9343 - loss: 0.1924 - val_accuracy: 0.9214 - val_loss: 0.1762
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 13s 340ms/step
#
# Performance on Test Data
# Precision: 0.9233074058157303
# Recall: 0.9148580968280468
# F1 Score: 0.915644392206595
# Accuracy: 0.9148580968280468
# Confusion Matrix:
#               Brown_Rust  Healthy  Yellow_Rust
# Brown_Rust          342        7           51
# Healthy               2      366           30
# Yellow_Rust           6        6          388
